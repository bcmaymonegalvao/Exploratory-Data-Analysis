# %% [markdown]
# # Exploratory Data Analysis
#
# The following notebook contains a series of Python operations aimed at performing exploratory data analysis on the **Titanic Survivors Dataset.**
#
# This script aims to answer the following question:
#
# - **Would it be possible to determine whether a Titanic passenger survived?**
#
# **Dataset:** https://www.kaggle.com/competitions/titanic/data

# %% [markdown]
# The dataset columns are:
#
# - **Passenger ID:** Unique number for each passenger.
# - **Survived:** Did the passenger survive? (0 = No, 1 = Yes).
# - **Pclass:** Passenger class (1 = First class, 2 = Second class, 3 = Third class).
# - **Name:** Passenger name.
# - **Sex:** Passenger gender.
# - **Age:** Passenger age.
# - **SibSp:** Number of siblings/spouse aboard the Titanic.
# - **Parch:** Number of parents/children aboard the Titanic.
# - **Ticket:** Ticket number.
# - **Fare:** Price of the ticket.
# - **Cabin:** Cabin number.
# - **Embarked:** Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %% [markdown]
# ### Importing and visualizing the dataset

# %%
# importing pandas
import pandas as pd

# %%
# importing the dataset
base = pd.read_csv('train.csv')

# %%
# Visualizing the first 3 lines
base.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Visualizing the last 3 lines
base.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Checking the dataset size
base.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Viewing a dataset summary

# %%
# Verifying the information
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Counting null values
base.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Viewing statical information
base.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Checking the number of distinct values in the database
base.nunique().sort_values(ascending = False).values
# Out:
# array([891, 891, 681, 248, 147,  88,   7,   7,   3,   3,   2,   2],
#       dtype=int64)

# %% [markdown]
# ### Visualizing graphically

# %%
# Importing matplotlib
import matplotlib.pyplot as plt

# %%
# Visualizando a informação acima de forma gráfica
fig, ax = plt.subplots()

ax.bar(base.nunique().sort_values(ascending = False).index, base.nunique().sort_values(ascending = False).values)

ax.tick_params(axis = 'x', labelrotation = 75)

plt.show()

# %%
# Visualizando a informação acima de forma gráfica em ordem decrescente

# %%
# Verificando o histograma das tarifas
fig, ax = plt.subplots()

ax.hist(base.Fare, bins=20)

plt.show()

# %%
base[base.Fare < 100].Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 838, dtype: float64

# %%
base.loc[base.Fare < 100, "Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 838, dtype: float64

# %%
# Verificando o histograma das tarifas apenas para tarifas menores que 100 reais
fig, ax = plt.subplots()

ax.hist(base[base.Fare < 100].Fare, bins=20)

plt.show()

# %% [markdown]
# ### O boxplot
# - Permite visualizar os percentis e valores máximo e mínimo dos dados
# - Permite visualizar, além de simetria e dispersão dos dados, valores extremos (outliers)
# - O valor máximo e mínimo são calculados baseado no interquartil

# %%
# Verificando para a coluna Fare
fig, ax = plt.subplots()
ax.boxplot(base.Fare)

plt.show()

# %% [markdown]
# **O que o boxplot mostra?**

# %% [markdown]
# ![img1-3.png](attachment:img1-3.png)

# %% [markdown]
# **Como eu tenho valores acima do valor máximo?**
# - max = Q3 + 1,5*interquartil
# - min  = Q1 - 1,5*interquartil
# <br><br>
# - E qual a importância disso?
#     - Pois nos ajuda a perceber outliers

# %%
# Podemos acessar qualquer um dos valores do .describe()
base.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# Determinando o interquartil
Q1 = base.Fare.describe()['25%']
Q3 = base.Fare.describe()['75%']
interquartil = Q3 - Q1

# Calculando o valor máximo
vlr_max = Q3 + 1.5*interquartil

# %%
vlr_max
# Out:
# 65.6344

# %%
interquartil
# Out:
# 23.0896

# %%
31.000000 - 7.910400
# Out:
# 23.0896

# %%
# Agora filtrando os valores acima do máximo
base[base.Fare > vlr_max]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Interpretando esses valores**

# %%
# Contando o número de linhas da base
base.shape[0]/4
# Out:
# 222.75

# %%
# Verificando a quantidade de registros em cada intervalo (<Q1, entre Q1 e Q2, entre Q2 e Q3,>Q3)
Q2 = base.Fare.describe()['50%']
base[base.Fare < Q2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ![img2.png](attachment:img2.png)

# %%
# Verificando para as colunas SibSp e Parch
fig, ax = plt.subplots(ncols=2, figsize=(12,8))

ax[0].boxplot(base.Fare)
ax[1].boxplot([base.SibSp, base.Parch])

plt.show()

# %% [markdown]
# **Qual o motivo do segundo boxplot ser mostrado dessa forma?**

# %%
# Verificando o value_counts()
base.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
# Verificando o resumo estatístico para essa coluna
base.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %% [markdown]
# ### Outras opções de gráficos

# %%
base.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()

x = base.Pclass.value_counts().index
y = base.Pclass.value_counts()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

plt.show()

# %%
base.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
base.Pclass.value_counts().index.astype('str')
# Out:
# Index(['3', '1', '2'], dtype='object', name='Pclass')

# %%
fig, ax = plt.subplots()

x = base.SibSp.value_counts().index.astype('str')
y = base.SibSp.value_counts()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

plt.show()

# %%
# Verificando se existe relação entre a coluna Parch e a idade
fig, ax = plt.subplots()

x = base.Parch
y = base.Age

ax.scatter(x, y)

plt.show()

# %% [markdown]
# **Criando uma matriz para mostrar a correlação de cada par de variáveis**
# - Podemos usar do pandas o `.plotting.scatter_matrix()` ou do seaborn o `.pairplot()`

# %%
# Utilizando o pandas
pd.plotting.scatter_matrix(base, figsize=(16,12))
plt.show()

# %%
# Utilizando o seaborn
import seaborn as sns

# %%
sns.pairplot(base, hue = 'Survived', diag_kind = hist")

plt.show()
# Out:
#   Cell In[40], line 1
#     sns.pairplot(base, hue = 'Survived', diag_kind = hist")
#                                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# **Visualizando apenas o KDE**
# - KDE: Kernel Density Estimation
#     - Mede a chance de uma variável aleatória assumir determinado valor
#     - A probabilidade é dada pela integral abaixo da curva na faixa de valor selecionada
# - Parece uma "versão de linha suavizada" de um histograma
# ![img3.png](attachment:img3.png)

# %% [markdown]
# **Para fazer o kde no seaborn, podemos usar o `sns.kdeplot`**

# %%
# Fazendo o kde para o Pclass
sns.kdeplot(data=base, x='Pclass', hue='Survived')
plt.show()

# %%
# Fazendo o kde para o Fare com e sem o Survived
sns.kdeplot(data = base, x = 'Fare')
plt.show()

# %% [markdown]
# ![img4.png](attachment:img4.png)

# %% [markdown]
# ### Heatmap de correlação

# %%
# Verificando a correlação entre os dados
base.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# Tornando visual
# cmap: https://matplotlib.org/stable/tutorials/colors/colormaps.html
sns.heatmap(base.corr(numeric_only=True), annot = True, cmap = "RdYlGn")
plt.show()

# %% [markdown]
# **Correlação**
# - Mostra o quanto duas variáveis estão relacionadas
# - Vai de -1 (forte correlação negativa) até +1 (forte correlação positiva), onde 0 acontece quando não existe correlação
# ![img5.png](attachment:img5.png)

# %% [markdown]
# ### Tratando valores vazios e outliers

# %% [markdown]
# #### Entendendo os outliers

# %%
# Verificando para a coluna Fare
fig, ax = plt.subplots()

ax.boxplot(base.Fare)

plt.show()

# %%
base[base.Fare > 300]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
base[base.Fare < 1]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
mean_Fare = base.Fare.mean()

# %%
# Substituindo os valores que são muito menores que a média
base.loc[base.Fare < 1, 'Fare'] = mean_Fare

# %%
# Filtrando apenas para esse valor muito maior que os demais

# %% [markdown]
# #### Entendendo os valores nulos

# %%
# Verificando a base
base[base.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Entendendo melhor os valores
base.loc[base.Age.isnull(), 'Survived'].value_counts()
# Out:
# Survived
# 0    125
# 1     52
# Name: count, dtype: int64

# %% [markdown]
# **Substituindo pelas média da idade**

# %%
# Calculando a média das idades
base.Age.mean()
# Out:
# 29.69911764705882

# %%
# Substituindo os valores nulos por essa média
base.loc[base.Age.isnull()] = base.Age.mean()

# %%
# Verificando novamente a base
base.loc[base.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
